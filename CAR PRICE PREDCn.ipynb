# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
from matplotlib.pyplot import xticks
import seaborn as sns

# %%
data = pd.read_csv("CarPrice_Assignment.csv")

# %%
data.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
data.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
data.price.describe()
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# max      45400.000000
# Name: price, dtype: float64

# %%
sns.distplot(data['price'])

# %%
data.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
plt = sns.countplot(data['symboling'])
plt.set(xlabel = 'Symbol', ylabel = 'Count')
pt.show()

# %%
avgsym = data[['symboling','price']].groupby("symboling").mean().plot(kind = 'bar', legend = False)
avgsym.set_xlabel("Symbol")
avgsym.set_ylabel("Avg Price(Dollars)")
pt.show()

# %%
data.CarName.values[0:20]
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 100ls', 'audi 5000', 'audi 4000',
#        'audi 5000s (diesel)', 'bmw 320i', 'bmw 320i', 'bmw x1', 'bmw x3',
#        'bmw z4', 'bmw x4', 'bmw x5', 'bmw x3', 'chevrolet impala',
#        'chevrolet monte carlo'], dtype=object)

# %%
data['Brand'] = data.CarName.str.split(' ').str.get(0).str.upper()
data.Brand.values[:]
arr = data["Brand"].unique()
print(arr)
# Out:
# ['ALFA-ROMERO' 'AUDI' 'BMW' 'CHEVROLET' 'DODGE' 'HONDA' 'ISUZU' 'JAGUAR'
#  'MAXDA' 'MAZDA' 'BUICK' 'MERCURY' 'MITSUBISHI' 'NISSAN' 'PEUGEOT'
#  'PLYMOUTH' 'PORSCHE' 'PORCSHCE' 'RENAULT' 'SAAB' 'SUBARU' 'TOYOTA'
#  'TOYOUTA' 'VOKSWAGEN' 'VOLKSWAGEN' 'VW' 'VOLVO']

# %%
len(set(data.Brand.values))
# Out:
# 27

# %%
fig, ax = pt.subplots(figsize = (20,10))
plt2 = sns.countplot(data['Brand'], order = pd.value_counts(data['Brand']).index,  )
plt2.set(xlabel = "Brand Name", ylabel = 'Count')
pt.show()
pt.tight_layout()

# %%
data['Brand'] = data['Brand'].replace(['VW', 'VOKSWAGEN'], 'VOLKSWAGEN')
data['Brand'] = data['Brand'].replace(['MAXDA'], 'MAZDA')
data['Brand'] = data['Brand'].replace(['PORCSHCE'], 'PORSCHE')
data['Brand'] = data['Brand'].replace(['TOYOUTA'], 'TOYOTA')

# %%
fig, ax = pt.subplots(figsize = (20,10))
plt2 = sns.countplot(data['Brand'], order = pd.value_counts(data['Brand']).index,  )
plt2.set(xlabel = "Brand Name", ylabel = 'Count')
pt.show()
pt.tight_layout()

# %%
len(set(data.Brand.values))
# Out:
# 22

# %%
data_comp_avg_price = data[['Brand','price']].groupby("Brand", as_index = False).mean().rename(columns={'price':'brand_avg_price'})
plt1 = data_comp_avg_price.plot(x = 'Brand', kind='bar',legend = False, sort_columns = True, figsize = (15,3))
plt1.set_xlabel("Brand")
plt1.set_ylabel("Avg Price (Dollars)")
xticks(rotation = 90)
pt.show()

# %%
data = data.merge(data_comp_avg_price, on = 'Brand')
data['brand_category'] = data['brand_avg_price'].apply(lambda x : "Budget" if x < 15000 else("Mid_Range" if 15000 <= x < 25000 else "Luxury"))

# %%
data.fueltype.values[:]
arr = data['fueltype'].unique()
print(arr)
# Out:
# ['gas' 'diesel']

# %%
data_fuel_avg_price = data[['fueltype', 'price']].groupby('fueltype',as_index = False).mean().rename(columns={'price':'fuel_avg_price'})
plt1 = data_fuel_avg_price.plot(x = 'fueltype',kind = 'bar', legend = False, sort_columns = True)
plt1.set_xlabel("Fuel Type")
plt1.set_ylabel("Avg Price")
pt.show()

# %%
aspir_avg_price = data[['aspiration','price']].groupby("aspiration",as_index = False).mean().rename(columns={'price':'aspir_avg_price'})
plt1 = aspir_avg_price.plot(x='aspiration',kind = 'bar',legend = False,sort_columns = True)
plt1.set_xlabel("Aspiration")
plt1.set_ylabel("Avg Price")
pt.show()

# %%
body_avg_price = data[['carbody','price']].groupby("carbody",as_index =False).mean().rename(columns={'price':'carbody_avg_price'})
plt1 = body_avg_price.plot(x = 'carbody',kind = 'bar', legend = False)
plt1.set_xlabel("Car body")
plt1.set_ylabel("Avg price")
pt.show()

# %%
dwheel_avg_price = data[['drivewheel','price']].groupby("drivewheel",as_index = False).mean().rename(columns={'price':'dwheel'})
plt1 = dwheel_avg_price.plot(x= 'drivewheel',kind = 'bar', legend = False)
plt1.set_xlabel("Drive Wheel")
plt1.set_ylabel("Avg price")
pt.show()

# %%
plt1 = sns.scatterplot(x = 'wheelbase', y='price', data= data)
plt1.set_xlabel("Wheelbase(inches)")
plt1.set_ylabel("price(dollars)")
pt.show()

# %%
plt1 = sns.scatterplot(x = 'carlength', y='price',hue = 'brand_category', data= data)
plt1.set_xlabel(" Length of Car(inches)")
plt1.set_ylabel("price(dollars)")
pt.show()
plt1 = sns.scatterplot(x = 'carwidth', y='price',hue = 'brand_category', data= data)
plt1.set_xlabel("width of car(inches)")
plt1.set_ylabel("price(dollars)")
pt.show()
plt1 = sns.scatterplot(x = 'carheight', y='price',hue = 'brand_category', data= data)
plt1.set_xlabel("height of car(inches)")
plt1.set_ylabel("price(dollars)")
pt.show()
plt1 = sns.scatterplot(x = 'curbweight', y='price',hue = 'brand_category', data= data)
plt1.set_xlabel("weight of car(inches)")
plt1.set_ylabel("price(dollars)")
pt.show()

# %%
engine_avg_price = data[['enginetype','price']].groupby("enginetype",as_index = False).mean().rename(columns={'price':'engine_avg_price'})
plt1 = engine_avg_price.plot(x= 'enginetype',kind = 'bar', legend = False)
plt1.set_xlabel("engine type")
plt1.set_ylabel("Avg price")
pt.show()
cylinder_avg_price = data[['cylindernumber','price']].groupby("cylindernumber",as_index = False).mean().rename(columns={'price':'cylinder_avg_price'})
plt1 = cylinder_avg_price.plot(x= 'cylindernumber',kind = 'bar', legend = False)
plt1.set_xlabel("Cylinder")
plt1.set_ylabel("Avg price")
pt.show()
fuelsys_avg_price = data[['fuelsystem','price']].groupby("fuelsystem",as_index = False).mean().rename(columns={'price':'fuelsys_avg_price'})
plt1 = fuelsys_avg_price.plot(x= 'fuelsystem',kind = 'bar', legend = False)
plt1.set_xlabel("Fuel System")
plt1.set_ylabel("Avg price")
pt.show()

# %%
plt1 = sns.scatterplot(x = 'enginesize', y = 'price',hue = 'brand_category',  data= data)
plt1.set_xlabel("Size of engine")
plt2.set_ylabel("Price of car")
pt.show()
plt1 = sns.scatterplot(x = 'boreratio', y = 'price',hue = 'brand_category',  data= data)
plt1.set_xlabel("Bore ratio")
plt2.set_ylabel("price of car")
pt.show()
plt1 = sns.scatterplot(x = 'stroke', y = 'price',hue = 'brand_category',  data= data)
plt1.set_xlabel("stroke")
plt2.set_ylabel("Price of car")
pt.show()
plt1 = sns.scatterplot(x = 'compressionratio', y = 'price',hue = 'brand_category',  data= data)
plt1.set_xlabel("Compression ratio")
plt2.set_ylabel("Price of car")
pt.show()
plt1 = sns.scatterplot(x = 'horsepower', y = 'price',hue = 'brand_category',  data= data)
plt1.set_xlabel("horse power")
plt2.set_ylabel("Price of car")
pt.show()
plt1 = sns.scatterplot(x = 'peakrpm', y = 'price',hue = 'brand_category',  data= data)
plt1.set_xlabel("Peak RPM")
plt2.set_ylabel("Price of car")
pt.show()

# %%
data['mileage'] = data['citympg']*0.55 + data['highwaympg']*0.45
plt1 = sns.scatterplot(x = 'mileage', y = 'price',hue = 'brand_category', data = data)
plt1.set_xlabel("Mlileage")
plt1.set_ylabel("Price of car")
pt.show()

# %%
auto = data[['Brand', 'fueltype', 'aspiration', 'carbody', 'drivewheel', 'wheelbase','carlength', 'carwidth', 'curbweight', 'enginetype', 'cylindernumber','fuelsystem', 'enginesize', 'boreratio', 'horsepower', 'mileage','price']]

# %%
auto.head()
# Out:
#          Brand fueltype aspiration      carbody drivewheel  wheelbase  \
# 0  ALFA-ROMERO      gas        std  convertible        rwd       88.6
# 1  ALFA-ROMERO      gas        std  convertible        rwd       88.6
# 2  ALFA-ROMERO      gas        std    hatchback        rwd       94.5
# 3         AUDI      gas        std        sedan        fwd       99.8
# 4         AUDI      gas        std        sedan        4wd       99.4
#
#    carlength  carwidth  curbweight enginetype cylindernumber fuelsystem  \
# 0      168.8      64.1        2548       dohc           four       mpfi
# 1      168.8      64.1        2548       dohc           four       mpfi
# 2      171.2      65.5        2823       ohcv            six       mpfi
# 3      176.6      66.2        2337        ohc           four       mpfi
# 4      176.6      66.4        2824        ohc           five       mpfi
#
#    enginesize  boreratio  horsepower  mileage    price
# 0         130       3.47         111    23.70  13495.0
# ...

# %%
pt.figure(figsize=(20,20))
sns.pairplot(auto)
pt.show()

# %%
brand_cat = pd.get_dummies(auto['Brand'],drop_first = True)
auto = pd.concat([auto, brand_cat])

# %%
fuel_type = pd.get_dummies(auto['fueltype'],drop_first = True)
auto = pd.concat([auto, fuel_type])

# %%
aspi_ration = pd.get_dummies(auto['aspiration'],drop_first = True)
auto = pd.concat([auto,aspi_ration])

# %%
car_body = pd.get_dummies(auto['carbody'],drop_first = True)
auto = pd.concat([auto,car_body])

# %%
engine_type = pd.get_dummies(auto['enginetype'],drop_first = True)
auto = pd.concat([auto,engine_type])

# %%
cylin_der = pd.get_dummies(auto['cylindernumber'],drop_first = True)
auto = pd.concat([auto,cylin_der])

# %%
fuel_system = pd.get_dummies(auto['fuelsystem'],drop_first = True)
auto = pd.concat([auto,fuel_system])

# %%
auto.drop(['fuelsystem','cylindernumber','enginetype','carbody','aspiration','fueltype','Brand'], axis = 1, inplace = True)

# %%
auto
# Out:
#     drivewheel  wheelbase  carlength  carwidth  curbweight  enginesize  \
# 0          rwd       88.6      168.8      64.1      2548.0       130.0
# 1          rwd       88.6      168.8      64.1      2548.0       130.0
# 2          rwd       94.5      171.2      65.5      2823.0       152.0
# 3          fwd       99.8      176.6      66.2      2337.0       109.0
# 4          4wd       99.4      176.6      66.4      2824.0       136.0
# ..         ...        ...        ...       ...         ...         ...
# 200        NaN        NaN        NaN       NaN         NaN         NaN
# 201        NaN        NaN        NaN       NaN         NaN         NaN
# 202        NaN        NaN        NaN       NaN         NaN         NaN
# 203        NaN        NaN        NaN       NaN         NaN         NaN
# 204        NaN        NaN        NaN       NaN         NaN         NaN
#
#      boreratio  horsepower  mileage    price  ...  three  twelve  two  2bbl  \
# ...

# %%
from sklearn.model_selection import train_test_split
np.random.seed(0)
data_train, data_test = train_test_split(auto,train_size = 0.8, test_size = 0.2, random_state = 100)

# %%
data_train
# Out:
#     drivewheel  wheelbase  carlength  carwidth  curbweight  enginesize  \
# 171        NaN        NaN        NaN       NaN         NaN         NaN
# 154        NaN        NaN        NaN       NaN         NaN         NaN
# 172        NaN        NaN        NaN       NaN         NaN         NaN
# 63         NaN        NaN        NaN       NaN         NaN         NaN
# 79         NaN        NaN        NaN       NaN         NaN         NaN
# ..         ...        ...        ...       ...         ...         ...
# 24         NaN        NaN        NaN       NaN         NaN         NaN
# 28         NaN        NaN        NaN       NaN         NaN         NaN
# 2          NaN        NaN        NaN       NaN         NaN         NaN
# 155        NaN        NaN        NaN       NaN         NaN         NaN
# 105        NaN        NaN        NaN       NaN         NaN         NaN
#
#      boreratio  horsepower  mileage  price  ...  three  twelve  two  2bbl  \
# ...

# %%
y_train = data_train.pop('price')
x_train = data_train

# %%
y_test = data_test.pop('price')
x_test = data_test

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-4719cf73997a> in <module>
# ----> 1 model.fit(x_train,y_train)
#
# D:\anaconda\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     490         n_jobs_ = self.n_jobs
#     491         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 492                          y_numeric=True, multi_output=True)
#     493
#     494         if sample_weight is not None:
#
# D:\anaconda\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     753                     ensure_min_features=ensure_min_features,
#     754                     warn_on_dtype=warn_on_dtype,
# ...
